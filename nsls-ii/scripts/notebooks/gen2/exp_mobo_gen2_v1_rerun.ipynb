# %%
import sys
import logging
import json
import numpy as np
import pandas as pd
from datetime import datetime
import time

from apsopt.core.optimizer import Optimizer, get_generator_class
from apsopt.core.evaluators import FunctionEvaluator
from apsopt.util.pydantic.options import AlgorithmOptions
from apsopt.util.pydantic.vocs import GVOCS

logger = logging.getLogger(__name__)

# %% [markdown]
# ### SETUP

# %%
# Load precomputed data

MODE = '6and3'
with open(f'lattice/data_{MODE}.json', 'r') as f:
    data_dict = json.load(f)
groups = data_dict['groups']
groups_direct = data_dict['groups_direct']
all_groups = {**groups, **groups_direct}
indices = data_dict['indices']
null_knobs = data_dict['null_knobs']
dfknobs = pd.read_json(f'lattice/dfknobs_{MODE}.json')

# impact of K2L difference
dfknobs.loc['SM2B',:] *= 0.25/0.2

# DO NOT CHANGE - USED TO CALCULATE ABSOLUTE K2L
initial_values_ref = {
    'SM1A': -23.68063424*0.2,
    'SM2B': 28.64315469*0.25,
    'SM1B': -25.94603546*0.2,
    'SL3': -29.46086061*0.2,
    'SL2': 35.67792145*0.2,
    'SL1': -13.27160605*0.2,
    'SH4': -15.82090071*0.2,
    'SH3': -5.85510841*0.2,
    'SH1': 19.8329121*0.2,
}

# CHANGE THIS TO VALUES FROM RING IF NEEDED
initial_values = initial_values_ref.copy()

initial_values['SM1A'] *= 1.01
initial_values['SM1B'] *= 1.008

# optimizer variables in units of K2L
variables = {'SVD0':[-0.6,0.6]} # this means SM1B will change by ~10%
# variables = {'SVD0':[-0.4,0.4]} # this means SM1B will change by ~10%

for k in ['SH1','SH3','SH4','SL1','SL2','SL3']:
    variables[k] = [-np.abs(initial_values_ref[k])*0.1,np.abs(initial_values_ref[k])*0.1]
    # variables[k] = [-np.abs(initial_values_ref[k])*0.075,np.abs(initial_values_ref[k])*0.075]

objectives_active = {'LT': 'MAXIMIZE', 'EFF':'MAXIMIZE'}

initial_variable_values = {k:0.0 for k in variables.keys()}

# Manual modifications
initial_variable_values['SH1'] -= 0.2
initial_variable_values['SH3'] -= 0.08
initial_variable_values['SL2'] -= 0.5
initial_variable_values['SL3'] -= 0.5

gvocs = GVOCS(variables=variables,
              variables_active=variables,
              objectives=objectives_active,
              objectives_active=objectives_active)

print(pd.DataFrame(initial_values_ref,index=[0]))
print(pd.DataFrame(variables))
# Out:
#        SM1A      SM2B      SM1B       SL3       SL2       SL1      SH4  \
# 0 -4.736127  7.160789 -5.189207 -5.892172  7.135584 -2.654321 -3.16418
#
#         SH3       SH1
# 0 -1.171022  3.966582
#    SVD0       SH1       SH3       SH4       SL1       SL2       SL3
# 0  -0.6 -0.396658 -0.117102 -0.316418 -0.265432 -0.713558 -0.589217
# 1   0.6  0.396658  0.117102  0.316418  0.265432  0.713558  0.589217

# %%
reference_point = {'LT': 3.0, # hours
                   'EFF': 10.0 # % injected
                   }

# %%
import sext_tools
def compute_family_k2l_from_knob_k2l(dfknobs, knobs_dict, debug=False):
    group_relative_strengths = sext_tools.knob_strengths_to_group_strengths(dfknobs, knobs_dict)
    for k in group_relative_strengths:
        if debug:
            print(f'{k}: {initial_values[k]:.3f} + {group_relative_strengths[k]:.3f} -> {initial_values[k]+group_relative_strengths[k]:.3f}')
        group_relative_strengths[k] = group_relative_strengths[k] + initial_values[k]
    return group_relative_strengths

# %%
#TEST = True
TEST = False

if TEST:
    from opt_funcs_nsls import make_dummy_eval
    eval_f = make_dummy_eval(gvocs)
else:
    sys.path.insert(0, "/nsls2/users/yhidaka/git_repos/nsls2scripts3/shifts/2023-11-26_APSU_DA_MA")
    import opt_funcs

    def knobs_to_family(inputs_dict):
        d = compute_family_k2l_from_knob_k2l(dfknobs, inputs_dict, True)
        return opt_funcs.master_eval_function(d, meas_bxb_tunes=True, meas_lifetime=True, meas_inj_eff=True)

    eval_f = knobs_to_family

# %%
inputs_dict = compute_family_k2l_from_knob_k2l(
    dfknobs, {k:variables[k][0] for k in variables.keys()}, True)
inputs_dict
# Out:
# SL1: -2.654 + -0.265 -> -2.920
# SL2: 7.136 + -0.714 -> 6.422
# SL3: -5.892 + -0.589 -> -6.481
# SH1: 3.967 + -0.397 -> 3.570
# SH3: -1.171 + -0.117 -> -1.288
# SH4: -3.164 + -0.316 -> -3.481
# SM1A: -4.783 + 0.398 -> -4.385
# SM1B: -5.231 + -0.447 -> -5.678
# SM2B: 7.161 + 0.052 -> 7.213
# {'SL1': -2.9197533310000003,
#  'SL2': 6.422025861000001,
#  'SL3': -6.481389334200001,
#  'SH1': 3.5699241780000004,
#  'SH3': -1.2881238501999999,
#  'SH4': -3.4805981562,
#  'SM1A': -4.385288760620001,
#  'SM1B': -5.6776103901960004,
#  'SM2B': 7.2127339758749995}

# %%
if True:
    opt_funcs.master_eval_function(inputs_dict, meas_bxb_tunes=True, meas_lifetime=True, meas_inj_eff=True)
# Out:
# Sextupole adj. took 8.4.
# RMS(dx, dy) [m] = (8.765e-05, 8.561e-06)
# RMS(dx, dy) [m] = (5.373e-05, 6.685e-06)
# RMS(dx, dy) [m] = (9.523e-05, 5.436e-06)
# RMS(dx, dy) [m] = (6.258e-05, 9.195e-06)
# RMS(dx, dy) [m] = (2.124e-05, 1.504e-06)
# RMS(dx, dy) [m] = (2.643e-05, 2.079e-06)
# RMS(dx, dy) [m] = (6.534e-06, 2.816e-06)
# Orbit correction converged
# ** # of outliers found = 0 (out of 180)
# Lifetime = 3.042 (raw tau [hr] = 3.731, epsy [pm] = 16.82) (took 5.2 [s])
# Inj. Eff. = 37.16 (took 18.5 [s])
# Eval. func. finished.

# %%
ev = FunctionEvaluator(script=eval_f)

generator_name = 'aps_mobo'
gc = get_generator_class(generator_name)

gen = gc(gvocs=gvocs)
gen.numerical_optimizer.n_raw_samples = 128 #512
gen.numerical_optimizer.n_restarts = 10
gen.gp_constructor.use_low_noise_prior = False
gen.gp_constructor.use_high_noise_prior = False
#gen.max_travel_distances = [0.1] * len(gvocs.variables_active)
gen.reference_point = reference_point

# %%
options = AlgorithmOptions(store_history=True, dump_every_step=True)
opt = Optimizer(options=options,
                generator=gen,
                evaluator=ev,
                gvocs=gvocs)

# %% [markdown]
# ### Sample at initial values

# %%
opt.generate_at(initial_variable_values)
opt.evaluate_data()
# Out:
# SL1: -2.654 + 0.000 -> -2.654
# SL2: 7.136 + -0.500 -> 6.636
# SL3: -5.892 + -0.500 -> -6.392
# SH1: 3.967 + -0.200 -> 3.767
# SH3: -1.171 + -0.080 -> -1.251
# SH4: -3.164 + 0.000 -> -3.164
# SM1A: -4.783 + 0.000 -> -4.783
# SM1B: -5.231 + 0.000 -> -5.231
# SM2B: 7.161 + 0.000 -> 7.161
# Sextupole adj. took 5.3.
# RMS(dx, dy) [m] = (2.090e-04, 6.592e-06)
# RMS(dx, dy) [m] = (2.040e-05, 3.995e-06)
# RMS(dx, dy) [m] = (6.566e-05, 4.643e-06)
# RMS(dx, dy) [m] = (8.740e-06, 1.328e-06)
# Orbit correction converged
# ** # of outliers found = 4 (out of 180)
# Lifetime = 3.786 (raw tau [hr] = 4.620, epsy [pm] = 16.63) (took 3.9 [s])
# Inj. Eff. = 2.99 (took 15.0 [s])
# Eval. func. finished.

# %%
opt.data
# Out:
#    SVD0  SH1   SH3  SH4  SL1  SL2  SL3  \
# 1   0.0 -0.2 -0.08  0.0  0.0 -0.5 -0.5
#
#                                               result exception traceback  ...  \
# 1  {'_nux': 0.2064655099190754, '_nuy': 0.2684310...      None            ...
#
#    valid      _nux      _nuy  _eps_x_bxbOn  _eps_y_bxbOn  _eps_x_bxbOff  \
# 1   True  0.206466  0.268431  2.228681e-09  1.670590e-11   2.242745e-09
#
#    _eps_y_bxbOff        LT   _raw_LT       EFF
# 1   1.662745e-11  3.785743  4.620131  2.992461
#
# [1 rows x 22 columns]

# %% [markdown]
# ### Sample close to initial point

# %%
mt = {k: 0.05 for k in variables.keys()}
opt.generate_random_around_point(n=1, point=initial_variable_values, spans=mt, use_normalized_distances=True)
opt.evaluate_data()
# Out:
# SL1: -2.654 + -0.008 -> -2.662
# SL2: 7.136 + -0.502 -> 6.633
# SL3: -5.892 + -0.496 -> -6.389
# SH1: 3.967 + -0.188 -> 3.779
# SH3: -1.171 + -0.082 -> -1.253
# SH4: -3.164 + 0.011 -> -3.153
# SM1A: -4.783 + -0.012 -> -4.795
# SM1B: -5.231 + 0.013 -> -5.217
# SM2B: 7.161 + -0.002 -> 7.159
# Sextupole adj. took 0.1.
# RMS(dx, dy) [m] = (3.401e-06, 9.484e-07)
# Orbit correction converged
# ** # of outliers found = 3 (out of 180)
# Lifetime = 3.889 (raw tau [hr] = 4.739, epsy [pm] = 16.59) (took 3.9 [s])
# Inj. Eff. = 1.64 (took 15.0 [s])
# Eval. func. finished.

# %%
opt.data
# Out:
#        SVD0       SH1       SH3       SH4       SL1       SL2       SL3  \
# 1  0.000000 -0.200000 -0.080000  0.000000  0.000000 -0.500000 -0.500000
# 2  0.017855 -0.187937 -0.081641  0.010791 -0.007804 -0.502309 -0.496378
#
#                                               result exception traceback  ...  \
# 1  {'_nux': 0.2064655099190754, '_nuy': 0.2684310...      None            ...
# 2  {'_nux': 0.205565248747958, '_nuy': 0.27068939...      None            ...
#
#    valid      _nux      _nuy  _eps_x_bxbOn  _eps_y_bxbOn  _eps_x_bxbOff  \
# 1   True  0.206466  0.268431  2.228681e-09  1.670590e-11   2.242745e-09
# 2   True  0.205565  0.270689  2.219011e-09  1.662855e-11   2.236210e-09
#
#    _eps_y_bxbOff        LT   _raw_LT       EFF
# 1   1.662745e-11  3.785743  4.620131  2.992461
# 2   1.658763e-11  3.889114  4.738622  1.638109
#
# [2 rows x 22 columns]

# %% [markdown]
# ### Run optimizer

# %%
opt.step()
# Out:
# /nsls2/users/yhidaka/.conda/envs/apsopt311/lib/python3.11/site-packages/botorch/optim/initializers.py:404: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# SL1: -2.654 + -0.145 -> -2.800
# SL2: 7.136 + -0.483 -> 6.653
# SL3: -5.892 + 0.149 -> -5.743
# SH1: 3.967 + -0.055 -> 3.911
# SH3: -1.171 + -0.106 -> -1.277
# SH4: -3.164 + 0.238 -> -2.926
# SM1A: -4.783 + -0.142 -> -4.926
# SM1B: -5.231 + 0.160 -> -5.071
# SM2B: 7.161 + -0.019 -> 7.142
# Sextupole adj. took 7.4.
# RMS(dx, dy) [m] = (3.573e-05, 2.602e-06)
# RMS(dx, dy) [m] = (6.415e-05, 4.238e-06)
# RMS(dx, dy) [m] = (1.474e-05, 2.736e-06)
# RMS(dx, dy) [m] = (2.681e-05, 3.483e-06)
# RMS(dx, dy) [m] = (7.464e-06, 1.103e-06)
# Orbit correction converged
# ** # of outliers found = 6 (out of 180)
# Lifetime = 4.989 (raw tau [hr] = 6.092, epsy [pm] = 16.67) (took 5.0 [s])
# Inj. Eff. = 33.29 (took 17.8 [s])
# Eval. func. finished.

# %%
for i in range(20):
    print(f'\n** Step #{i+1} at {datetime.now():%Y-%m-%d %H:%M:%S}**\n')
    opt.step()
# Out:
# ** Step #1 at 2023-11-26 21:42:59**
#
# SL1: -2.654 + -0.185 -> -2.839
# SL2: 7.136 + -0.478 -> 6.658
# SL3: -5.892 + 0.380 -> -5.512
# SH1: 3.967 + -0.017 -> 3.950
# SH3: -1.171 + -0.113 -> -1.284
# SH4: -3.164 + 0.303 -> -2.861
# SM1A: -4.783 + -0.180 -> -4.964
# SM1B: -5.231 + 0.202 -> -5.029
# SM2B: 7.161 + -0.024 -> 7.137
# Sextupole adj. took 2.2.
# RMS(dx, dy) [m] = (2.648e-05, 1.064e-06)
# RMS(dx, dy) [m] = (1.360e-05, 5.033e-06)
# RMS(dx, dy) [m] = (9.585e-06, 2.196e-06)
# Orbit correction converged
# ** # of outliers found = 9 (out of 180)
# Lifetime = 5.321 (raw tau [hr] = 6.602, epsy [pm] = 17.15) (took 8.6 [s])
# Inj. Eff. = 84.77 (took 18.8 [s])
# Eval. func. finished.
#
# ** Step #2 at 2023-11-26 21:43:41**
#
# SL1: -2.654 + -0.225 -> -2.880
# SL2: 7.136 + -0.473 -> 6.663
# SL3: -5.892 + 0.571 -> -5.321
# SH1: 3.967 + 0.024 -> 3.990
# SH3: -1.171 + -0.117 -> -1.288
# SH4: -3.164 + 0.316 -> -2.848
# SM1A: -4.783 + -0.220 -> -5.003
# SM1B: -5.231 + 0.247 -> -4.984
# SM2B: 7.161 + -0.029 -> 7.132
# Sextupole adj. took 2.2.
# RMS(dx, dy) [m] = (3.169e-05, 1.812e-06)
# RMS(dx, dy) [m] = (6.485e-05, 3.989e-06)
# RMS(dx, dy) [m] = (1.236e-05, 1.847e-06)
# RMS(dx, dy) [m] = (6.705e-06, 1.833e-06)
# Orbit correction converged
# ** # of outliers found = 2 (out of 180)
# Lifetime = 5.700 (raw tau [hr] = 7.191, epsy [pm] = 17.71) (took 4.4 [s])
# Inj. Eff. = 82.81 (took 18.4 [s])
# Eval. func. finished.
#
# ** Step #3 at 2023-11-26 21:44:22**
#
# SL1: -2.654 + -0.265 -> -2.920
# SL2: 7.136 + -0.460 -> 6.675
# SL3: -5.892 + 0.396 -> -5.496
# SH1: 3.967 + 0.096 -> 4.063
# SH3: -1.171 + -0.117 -> -1.288
# SH4: -3.164 + 0.316 -> -2.848
# SM1A: -4.783 + -0.292 -> -5.075
# SM1B: -5.231 + 0.327 -> -4.903
# SM2B: 7.161 + -0.038 -> 7.123
# Sextupole adj. took 2.1.
# RMS(dx, dy) [m] = (3.542e-05, 1.661e-06)
# RMS(dx, dy) [m] = (1.460e-05, 1.753e-06)
# RMS(dx, dy) [m] = (7.121e-06, 1.373e-06)
# Orbit correction converged
# ** # of outliers found = 7 (out of 180)
# Lifetime = 5.518 (raw tau [hr] = 7.034, epsy [pm] = 18.04) (took 8.0 [s])
# Inj. Eff. = 83.06 (took 18.4 [s])
# Eval. func. finished.
#
# ** Step #4 at 2023-11-26 21:45:05**
#
# SL1: -2.654 + -0.265 -> -2.920
# SL2: 7.136 + -0.526 -> 6.610
# SL3: -5.892 + 0.469 -> -5.424
# SH1: 3.967 + 0.093 -> 4.060
# SH3: -1.171 + -0.117 -> -1.288
# SH4: -3.164 + 0.316 -> -2.848
# SM1A: -4.783 + -0.113 -> -4.896
# SM1B: -5.231 + 0.127 -> -5.104
# SM2B: 7.161 + -0.015 -> 7.146
# Sextupole adj. took 2.1.
# RMS(dx, dy) [m] = (3.355e-05, 2.552e-06)
# RMS(dx, dy) [m] = (2.277e-05, 2.764e-06)
# RMS(dx, dy) [m] = (7.892e-06, 2.722e-06)
# Orbit correction converged
# ** # of outliers found = 10 (out of 180)
# Lifetime = 5.676 (raw tau [hr] = 7.265, epsy [pm] = 18.16) (took 6.3 [s])
# Inj. Eff. = 74.40 (took 18.8 [s])
# Eval. func. finished.
#
# ** Step #5 at 2023-11-26 21:45:50**
#
# SL1: -2.654 + -0.265 -> -2.920
# SL2: 7.136 + -0.333 -> 6.802
# SL3: -5.892 + 0.465 -> -5.428
# SH1: 3.967 + -0.055 -> 3.912
# SH3: -1.171 + -0.117 -> -1.288
# SH4: -3.164 + 0.316 -> -2.848
# SM1A: -4.783 + -0.236 -> -5.019
# SM1B: -5.231 + 0.265 -> -4.966
# SM2B: 7.161 + -0.031 -> 7.130
# Sextupole adj. took 2.1.
# RMS(dx, dy) [m] = (5.252e-05, 1.873e-06)
# RMS(dx, dy) [m] = (1.517e-05, 1.840e-06)
# RMS(dx, dy) [m] = (6.276e-06, 6.986e-07)
# Orbit correction converged
# ** # of outliers found = 9 (out of 180)
# Lifetime = 5.248 (raw tau [hr] = 6.741, epsy [pm] = 18.27) (took 6.9 [s])
# Inj. Eff. = 80.75 (took 20.0 [s])
# Eval. func. finished.
#
# ** Step #6 at 2023-11-26 21:46:33**
#
# SL1: -2.654 + -0.162 -> -2.816
# SL2: 7.136 + -0.430 -> 6.706
# SL3: -5.892 + 0.477 -> -5.415
# SH1: 3.967 + 0.092 -> 4.059
# SH3: -1.171 + -0.117 -> -1.288
# SH4: -3.164 + 0.316 -> -2.848
# SM1A: -4.783 + -0.258 -> -5.041
# SM1B: -5.231 + 0.289 -> -4.941
# SM2B: 7.161 + -0.034 -> 7.127
# Sextupole adj. took 1.1.
# RMS(dx, dy) [m] = (1.085e-06, 1.735e-06)
# Orbit correction converged
# ** # of outliers found = 8 (out of 180)
# Lifetime = 5.396 (raw tau [hr] = 6.938, epsy [pm] = 18.28) (took 5.0 [s])
# Inj. Eff. = 81.89 (took 19.7 [s])
# Eval. func. finished.
#
# ** Step #7 at 2023-11-26 21:47:07**
#
# SL1: -2.654 + -0.228 -> -2.882
# SL2: 7.136 + -0.647 -> 6.489
# SL3: -5.892 + 0.472 -> -5.421
# SH1: 3.967 + -0.010 -> 3.957
# SH3: -1.171 + -0.117 -> -1.288
# SH4: -3.164 + 0.316 -> -2.848
# SM1A: -4.783 + -0.277 -> -5.060
# SM1B: -5.231 + 0.311 -> -4.920
# SM2B: 7.161 + -0.036 -> 7.125
# Sextupole adj. took 2.1.
# RMS(dx, dy) [m] = (3.923e-05, 1.620e-06)
# RMS(dx, dy) [m] = (1.396e-05, 1.698e-06)
# RMS(dx, dy) [m] = (7.899e-06, 2.626e-06)
# Orbit correction converged
# ** # of outliers found = 5 (out of 180)
# Lifetime = 4.534 (raw tau [hr] = 5.832, epsy [pm] = 18.28) (took 5.0 [s])
# Inj. Eff. = 86.26 (took 18.8 [s])
# Eval. func. finished.
#
# ** Step #8 at 2023-11-26 21:47:45**
#
# SL1: -2.654 + -0.241 -> -2.896
# SL2: 7.136 + -0.454 -> 6.681
# SL3: -5.892 + 0.490 -> -5.402
# SH1: 3.967 + 0.041 -> 4.008
# SH3: -1.171 + -0.086 -> -1.257
# SH4: -3.164 + 0.316 -> -2.848
# SM1A: -4.783 + -0.218 -> -5.002
# SM1B: -5.231 + 0.245 -> -4.986
# SM2B: 7.161 + -0.028 -> 7.132
# Sextupole adj. took 2.1.
# RMS(dx, dy) [m] = (5.220e-05, 1.788e-06)
# RMS(dx, dy) [m] = (3.477e-05, 3.220e-06)
# RMS(dx, dy) [m] = (8.436e-06, 1.735e-06)
# Orbit correction converged
# ** # of outliers found = 7 (out of 180)
# Lifetime = 5.624 (raw tau [hr] = 7.240, epsy [pm] = 18.29) (took 4.9 [s])
# Inj. Eff. = 81.37 (took 20.1 [s])
# Eval. func. finished.
#
# ** Step #9 at 2023-11-26 21:48:26**
#
# SL1: -2.654 + -0.265 -> -2.920
# SL2: 7.136 + -0.455 -> 6.680
# SL3: -5.892 + 0.589 -> -5.303
# SH1: 3.967 + 0.092 -> 4.059
# SH3: -1.171 + -0.117 -> -1.288
# SH4: -3.164 + 0.311 -> -2.853
# SM1A: -4.783 + -0.148 -> -4.932
# SM1B: -5.231 + 0.167 -> -5.064
# SM2B: 7.161 + -0.019 -> 7.141
# Sextupole adj. took 1.1.
# RMS(dx, dy) [m] = (2.703e-05, 1.042e-06)
# RMS(dx, dy) [m] = (5.501e-05, 1.779e-06)
# RMS(dx, dy) [m] = (1.409e-05, 2.148e-06)
# RMS(dx, dy) [m] = (8.942e-06, 7.766e-07)
# Orbit correction converged
# ** # of outliers found = 4 (out of 180)
# Lifetime = 5.757 (raw tau [hr] = 7.425, epsy [pm] = 18.34) (took 5.4 [s])
# Inj. Eff. = 81.12 (took 20.3 [s])
# Eval. func. finished.
#
# ** Step #10 at 2023-11-26 21:49:09**
#
# SL1: -2.654 + -0.257 -> -2.911
# SL2: 7.136 + -0.469 -> 6.666
# SL3: -5.892 + 0.544 -> -5.348
# SH1: 3.967 + 0.059 -> 4.026
# SH3: -1.171 + -0.117 -> -1.288
# SH4: -3.164 + 0.221 -> -2.943
# SM1A: -4.783 + -0.226 -> -5.010
# SM1B: -5.231 + 0.254 -> -4.977
# SM2B: 7.161 + -0.029 -> 7.131
# Sextupole adj. took 1.1.
# RMS(dx, dy) [m] = (1.097e-06, 8.709e-07)
# Orbit correction converged
# ** # of outliers found = 6 (out of 180)
# Lifetime = 5.428 (raw tau [hr] = 7.005, epsy [pm] = 18.34) (took 6.5 [s])
# Inj. Eff. = 82.57 (took 19.3 [s])
# Eval. func. finished.
#
# ** Step #11 at 2023-11-26 21:49:43**
#
# SL1: -2.654 + -0.205 -> -2.859
# SL2: 7.136 + -0.494 -> 6.641
# SL3: -5.892 + 0.427 -> -5.465
# SH1: 3.967 + -0.011 -> 3.956
# SH3: -1.171 + -0.117 -> -1.288
# SH4: -3.164 + 0.294 -> -2.870
# SM1A: -4.783 + -0.258 -> -5.042
# SM1B: -5.231 + 0.290 -> -4.941
# SM2B: 7.161 + -0.034 -> 7.127
# Sextupole adj. took 1.1.
# RMS(dx, dy) [m] = (1.450e-06, 8.090e-07)
# Orbit correction converged
# ** # of outliers found = 6 (out of 180)
# Lifetime = 5.148 (raw tau [hr] = 6.647, epsy [pm] = 18.34) (took 6.0 [s])
# Inj. Eff. = 86.70 (took 21.1 [s])
# Eval. func. finished.
#
# ** Step #12 at 2023-11-26 21:50:19**
#
# SL1: -2.654 + -0.265 -> -2.920
# SL2: 7.136 + -0.470 -> 6.666
# SL3: -5.892 + 0.589 -> -5.303
# SH1: 3.967 + 0.171 -> 4.137
# SH3: -1.171 + -0.117 -> -1.288
# SH4: -3.164 + 0.316 -> -2.848
# SM1A: -4.783 + -0.298 -> -5.082
# SM1B: -5.231 + 0.335 -> -4.896
# SM2B: 7.161 + -0.039 -> 7.122
# Sextupole adj. took 2.1.
# RMS(dx, dy) [m] = (4.291e-05, 2.196e-06)
# RMS(dx, dy) [m] = (1.422e-05, 1.480e-06)
# RMS(dx, dy) [m] = (2.420e-05, 1.939e-06)
# RMS(dx, dy) [m] = (1.853e-05, 1.073e-06)
# RMS(dx, dy) [m] = (4.038e-06, 1.112e-06)
# Orbit correction converged
# ** # of outliers found = 4 (out of 180)
# Lifetime = 5.663 (raw tau [hr] = 7.318, epsy [pm] = 18.35) (took 6.2 [s])
# Inj. Eff. = 75.14 (took 19.2 [s])
# Eval. func. finished.
#
# ** Step #13 at 2023-11-26 21:51:07**
#
# SL1: -2.654 + -0.166 -> -2.821
# SL2: 7.136 + -0.462 -> 6.674
# SL3: -5.892 + 0.589 -> -5.303
# SH1: 3.967 + -0.032 -> 3.934
# SH3: -1.171 + -0.100 -> -1.271
# SH4: -3.164 + 0.271 -> -2.893
# SM1A: -4.783 + -0.067 -> -4.851
# SM1B: -5.231 + 0.075 -> -5.155
# SM2B: 7.161 + -0.009 -> 7.152
# Sextupole adj. took 3.2.
# RMS(dx, dy) [m] = (4.023e-05, 1.313e-06)
# RMS(dx, dy) [m] = (2.207e-05, 1.927e-06)
# RMS(dx, dy) [m] = (1.210e-05, 1.687e-06)
# RMS(dx, dy) [m] = (8.091e-06, 2.253e-06)
# Orbit correction converged
# ** # of outliers found = 5 (out of 180)
# Lifetime = 5.729 (raw tau [hr] = 7.416, epsy [pm] = 18.39) (took 4.0 [s])
# Inj. Eff. = 80.58 (took 21.0 [s])
# Eval. func. finished.
#
# ** Step #14 at 2023-11-26 21:51:52**
#
# SL1: -2.654 + -0.205 -> -2.859
# SL2: 7.136 + -0.473 -> 6.663
# SL3: -5.892 + 0.589 -> -5.303
# SH1: 3.967 + 0.072 -> 4.038
# SH3: -1.171 + -0.092 -> -1.263
# SH4: -3.164 + 0.316 -> -2.848
# SM1A: -4.783 + -0.048 -> -4.832
# SM1B: -5.231 + 0.054 -> -5.176
# SM2B: 7.161 + -0.006 -> 7.154
# Sextupole adj. took 1.1.
# RMS(dx, dy) [m] = (1.681e-06, 1.169e-06)
# Orbit correction converged
# ** # of outliers found = 7 (out of 180)
# Lifetime = 6.050 (raw tau [hr] = 7.847, epsy [pm] = 18.44) (took 6.0 [s])
# Inj. Eff. = 79.31 (took 19.4 [s])
# Eval. func. finished.
#
# ** Step #15 at 2023-11-26 21:52:28**
#
# SL1: -2.654 + -0.182 -> -2.836
# SL2: 7.136 + -0.465 -> 6.671
# SL3: -5.892 + 0.589 -> -5.303
# SH1: 3.967 + 0.130 -> 4.096
# SH3: -1.171 + -0.104 -> -1.275
# SH4: -3.164 + 0.316 -> -2.848
# SM1A: -4.783 + 0.096 -> -4.688
# SM1B: -5.231 + -0.108 -> -5.338
# SM2B: 7.161 + 0.013 -> 7.173
# Sextupole adj. took 1.1.
# RMS(dx, dy) [m] = (4.819e-05, 1.357e-06)
# RMS(dx, dy) [m] = (5.778e-06, 2.051e-06)
# Orbit correction converged
# ** # of outliers found = 3 (out of 180)
# Lifetime = 6.234 (raw tau [hr] = 8.106, epsy [pm] = 18.52) (took 5.1 [s])
# Inj. Eff. = 65.21 (took 19.3 [s])
# Eval. func. finished.
#
# ** Step #16 at 2023-11-26 21:53:04**
#
# SL1: -2.654 + -0.173 -> -2.827
# SL2: 7.136 + -0.545 -> 6.591
# SL3: -5.892 + 0.401 -> -5.491
# SH1: 3.967 + -0.032 -> 3.935
# SH3: -1.171 + -0.097 -> -1.268
# SH4: -3.164 + 0.316 -> -2.848
# SM1A: -4.783 + -0.298 -> -5.081
# SM1B: -5.231 + 0.334 -> -4.897
# SM2B: 7.161 + -0.039 -> 7.122
# Sextupole adj. took 5.2.
# RMS(dx, dy) [m] = (6.348e-05, 5.300e-06)
# RMS(dx, dy) [m] = (2.686e-05, 4.686e-06)
# RMS(dx, dy) [m] = (4.005e-05, 4.813e-06)
# RMS(dx, dy) [m] = (6.305e-06, 1.567e-06)
# Orbit correction converged
# ** # of outliers found = 2 (out of 180)
# Lifetime = 4.650 (raw tau [hr] = 6.037, epsy [pm] = 18.44) (took 5.2 [s])
# Inj. Eff. = 88.61 (took 20.1 [s])
# Eval. func. finished.
#
# ** Step #17 at 2023-11-26 21:53:52**
#
# SL1: -2.654 + -0.265 -> -2.920
# SL2: 7.136 + -0.528 -> 6.607
# SL3: -5.892 + 0.589 -> -5.303
# SH1: 3.967 + -0.104 -> 3.862
# SH3: -1.171 + -0.072 -> -1.243
# SH4: -3.164 + 0.244 -> -2.920
# SM1A: -4.783 + -0.191 -> -4.975
# SM1B: -5.231 + 0.215 -> -5.016
# SM2B: 7.161 + -0.025 -> 7.136
# Sextupole adj. took 2.1.
# RMS(dx, dy) [m] = (9.406e-05, 4.645e-06)
# RMS(dx, dy) [m] = (3.698e-05, 2.481e-06)
# RMS(dx, dy) [m] = (1.015e-05, 2.174e-06)
# RMS(dx, dy) [m] = (1.221e-05, 1.418e-06)
# RMS(dx, dy) [m] = (4.430e-06, 5.550e-07)
# Orbit correction converged
# ** # of outliers found = 3 (out of 180)
# Lifetime = 4.883 (raw tau [hr] = 6.355, epsy [pm] = 18.52) (took 5.2 [s])
# Inj. Eff. = 86.11 (took 20.0 [s])
# Eval. func. finished.
#
# ** Step #18 at 2023-11-26 21:54:38**
#
# SL1: -2.654 + -0.187 -> -2.841
# SL2: 7.136 + -0.407 -> 6.729
# SL3: -5.892 + 0.589 -> -5.303
# SH1: 3.967 + 0.111 -> 4.078
# SH3: -1.171 + -0.106 -> -1.277
# SH4: -3.164 + 0.316 -> -2.848
# SM1A: -4.783 + 0.041 -> -4.742
# SM1B: -5.231 + -0.046 -> -5.277
# SM2B: 7.161 + 0.005 -> 7.166
# Sextupole adj. took 3.2.
# RMS(dx, dy) [m] = (1.050e-04, 4.341e-06)
# RMS(dx, dy) [m] = (1.332e-05, 2.782e-06)
# RMS(dx, dy) [m] = (1.398e-05, 3.071e-06)
# RMS(dx, dy) [m] = (1.789e-05, 1.088e-06)
# RMS(dx, dy) [m] = (9.721e-06, 1.557e-06)
# Orbit correction converged
# ** # of outliers found = 2 (out of 180)
# Lifetime = 6.844 (raw tau [hr] = 8.919, epsy [pm] = 18.54) (took 5.6 [s])
# Inj. Eff. = 75.66 (took 20.3 [s])
# Eval. func. finished.
#
# ** Step #19 at 2023-11-26 21:55:28**
#
# SL1: -2.654 + -0.184 -> -2.838
# SL2: 7.136 + -0.340 -> 6.796
# SL3: -5.892 + 0.589 -> -5.303
# SH1: 3.967 + 0.123 -> 4.089
# SH3: -1.171 + -0.108 -> -1.279
# SH4: -3.164 + 0.316 -> -2.848
# SM1A: -4.783 + 0.018 -> -4.766
# SM1B: -5.231 + -0.020 -> -5.250
# SM2B: 7.161 + 0.002 -> 7.163
# Sextupole adj. took 0.1.
# RMS(dx, dy) [m] = (1.205e-06, 9.780e-07)
# Orbit correction converged
# ** # of outliers found = 4 (out of 180)
# Lifetime = 6.415 (raw tau [hr] = 8.373, epsy [pm] = 18.58) (took 5.5 [s])
# Inj. Eff. = 69.21 (took 19.2 [s])
# Eval. func. finished.
#
# ** Step #20 at 2023-11-26 21:56:01**
#
# SL1: -2.654 + -0.178 -> -2.832
# SL2: 7.136 + -0.444 -> 6.692
# SL3: -5.892 + 0.485 -> -5.407
# SH1: 3.967 + -0.113 -> 3.854
# SH3: -1.171 + -0.088 -> -1.259
# SH4: -3.164 + 0.223 -> -2.941
# SM1A: -4.783 + -0.325 -> -5.108
# SM1B: -5.231 + 0.364 -> -4.866
# SM2B: 7.161 + -0.042 -> 7.118
# Sextupole adj. took 4.2.
# RMS(dx, dy) [m] = (4.524e-05, 2.254e-06)
# RMS(dx, dy) [m] = (1.830e-05, 2.395e-06)
# RMS(dx, dy) [m] = (1.279e-05, 8.871e-06)
# RMS(dx, dy) [m] = (3.929e-06, 1.115e-06)
# Orbit correction converged
# ** # of outliers found = 3 (out of 180)
# Lifetime = 4.447 (raw tau [hr] = 5.802, epsy [pm] = 18.55) (took 4.6 [s])
# Inj. Eff. = 81.05 (took 18.7 [s])
# Eval. func. finished.

# %%
opt.data.tail()
# Out:
#         SVD0       SH1       SH3       SH4       SL1       SL2       SL3  \
# 19  0.448274 -0.031850 -0.097344  0.316418 -0.172918 -0.544588  0.401158
# 20  0.288301 -0.104273 -0.072406  0.243783 -0.265432 -0.528253  0.589217
# 21 -0.062415  0.111094 -0.105969  0.316418 -0.186656 -0.406611  0.589217
# 22 -0.026547  0.122723 -0.107908  0.316418 -0.183844 -0.339881  0.589217
# 23  0.489028 -0.112907 -0.088103  0.223076 -0.178138 -0.444048  0.485333
#
#                                                result exception traceback  \
# 19  {'_nux': 0.21099733959289255, '_nuy': 0.254942...      None
# 20  {'_nux': 0.21209596863279725, '_nuy': 0.253080...      None
# 21  {'_nux': 0.21449666508911033, '_nuy': 0.249449...      None
# 22  {'_nux': 0.21449666508911033, '_nuy': 0.249428...      None
# 23  {'_nux': 0.21136354479410827, '_nuy': 0.255094...      None
#
#     ...  valid      _nux      _nuy  _eps_x_bxbOn  _eps_y_bxbOn  _eps_x_bxbOff  \
# 19  ...   True  0.210997  0.254942  2.206942e-09  1.816372e-11   2.206555e-09
# 20  ...   True  0.212096  0.253081  2.202067e-09  1.888306e-11   2.206555e-09
# 21  ...   True  0.214497  0.249449  2.155315e-09  2.183640e-11   2.205997e-09
# 22  ...   True  0.214497  0.249429  2.165104e-09  2.125212e-11   2.205749e-09
# 23  ...   True  0.211364  0.255095  2.218394e-09  1.835304e-11   2.205588e-09
#
#     _eps_y_bxbOff        LT   _raw_LT        EFF
# 19   1.844294e-11  4.649818  6.036956  88.606741
# 20   1.851584e-11  4.883263  6.355443  86.114643
# 21   1.854160e-11  6.844431  8.918873  75.659465
# 22   1.858232e-11  6.414922  8.372707  69.207155
# 23   1.854823e-11  4.447392  5.801908  81.054857
#
# [5 rows x 22 columns]

# %%
import matplotlib.pyplot as plt

hvs = []
for i in range(1,len(opt.data)):
    hv = opt.generator.calculate_hypervolume_at(i)
    hvs.append(hv)

fig,ax = plt.subplots(1,2,squeeze=False,figsize=(12,6))
df = opt.data
ol = ['EFF', 'LT']
l = ax[0,0].scatter(df.loc[:,ol[0]], df.loc[:,ol[1]],10,marker='o',c=range(len(df)),vmax=len(df))
ax[0,0].scatter(df.loc[:1,ol[0]], df.loc[:1,ol[1]], 20,marker='o',c='red',label='initial point')
ax[0,0].scatter(gen.reference_point[ol[0]], gen.reference_point[ol[1]],40,marker='*',c='black',label='reference point')
ax[0,0].set_xlabel(ol[0])
ax[0,0].set_ylabel(ol[1])
fig.colorbar(l)
ax[0,0].legend()

ax[0,1].plot(hvs,marker='o')
ax[0,1].set_xlabel('Step #')
ax[0,1].set_ylabel('Hypervolume')
# Out:
# Text(0, 0.5, 'Hypervolume')

# %%
fig,ax = plt.subplots(1,2,squeeze=False,figsize=(8,6))
df = opt.data

ax[0,0].plot(df.loc[:,'_nux'], marker='o', label='nux')
ax[0,0].plot(df.loc[:,'_nuy'], marker='o', label='nuy')
ax[0,1].plot(df.loc[:,'_eps_x_bxbOn'], marker='o', label='eps_x_bxbOn', color='red')
ax[0,1].plot(df.loc[:,'_eps_y_bxbOn']*1e2, marker='o', label='eps_y_bxbOn', color='green')
ax[0,0].set_xlabel('Step #')
ax[0,0].set_ylabel('Tune')
ax[0,0].legend()
ax[0,1].legend()

# %%
# This will save optimizer state
from datetime import datetime
opt.state_to_json(f'{datetime.now():%Y%m%dT%H%M%S}_exp_mobo_{MODE}_v1_dump.json')
# Out:
# '{\n  "optimizer": {\n    "tag": "3d9b04d587",\n    "store_history": true,\n    "dump_every_step": true,\n    "history_directory": null,\n    "execution_mode": "sync"\n  },\n  "generator": {\n    "name": "aps_mobo",\n    "n_monte_carlo_samples": 128,\n    "turbo_controller": null,\n    "use_cuda": false,\n    "gp_constructor": {\n      "name": "mobo_model",\n      "use_low_noise_prior": false,\n      "covar_modules": {},\n      "mean_modules": {},\n      "trainable_mean_keys": [],\n      "use_high_noise_prior": false\n    },\n    "numerical_optimizer": {\n      "name": "APSLBFGS",\n      "n_raw_samples": 128,\n      "n_restarts": 10,\n      "max_iter": 2000,\n      "sequential": true\n    },\n    "max_travel_distances": null,\n    "fixed_features": null,\n    "computation_time": null,\n    "n_candidates": 1,\n    "reference_point": {\n      "LT": 3.0,\n      "EFF": 10.0\n    },\n    "prune_inferior_points_kwargs": null\n  },\n  "evaluator": {\n    "name": "func",\n    "on_error": "ignore",\n    "max_workers": 1,\n    "script": "__main__.knobs_to_family",\n    "post_script": null,\n    "script_kwargs": {},\n    "eval_cnt": 23,\n    "TRACE": true\n  },\n  "gvocs": {\n    "variables": {\n      "SVD0": [\n        -0.6,\n        0.6\n      ],\n      "SH1": [\n        -0.39665824200000005,\n        0.39665824200000005\n      ],\n      "SH3": [\n        -0.1171021682,\n        0.1171021682\n      ],\n      "SH4": [\n        -0.31641801420000004,\n        0.31641801420000004\n      ],\n      "SL1": [\n        -0.2654321210000001,\n        0.2654321210000001\n      ],\n      "SL2": [\n        -0.7135584290000001,\n        0.7135584290000001\n      ],\n      "SL3": [\n        -0.5892172122000001,\n        0.5892172122000001\n      ]\n    },\n    "variables_active": {\n      "SVD0": [\n        -0.6,\n        0.6\n      ],\n      "SH1": [\n        -0.39665824200000005,\n        0.39665824200000005\n      ],\n      "SH3": [\n        -0.1171021682,\n        0.1171021682\n      ],\n      "SH4": [\n        -0.31641801420000004,\n        0.31641801420000004\n      ],\n      "SL1": [\n        -0.2654321210000001,\n        0.2654321210000001\n      ],\n      "SL2": [\n        -0.7135584290000001,\n        0.7135584290000001\n      ],\n      "SL3": [\n        -0.5892172122000001,\n        0.5892172122000001\n      ]\n    },\n    "auxiliary": {},\n    "readbacks": {},\n    "constraints": {},\n    "constraints_active": {},\n    "objectives": {\n      "LT": "MAXIMIZE",\n      "EFF": "MAXIMIZE"\n    },\n    "objectives_active": {\n      "LT": "MAXIMIZE",\n      "EFF": "MAXIMIZE"\n    },\n    "observables": [],\n    "atol": {\n      "SH1": 0.05,\n      "SH3": 0.05,\n      "SH4": 0.05,\n      "SL1": 0.05,\n      "SL2": 0.05,\n      "SL3": 0.05,\n      "SVD0": 0.05\n    },\n    "initial_change": {},\n    "constants": {},\n    "linked_variables": {},\n    "knobs": {},\n    "knobs_initial_values": {}\n  },\n  "data": {\n    "input_data": {\n      "1": {\n        "SVD0": 0.0,\n        "SH1": -0.2,\n        "SH3": -0.08,\n        "SH4": 0.0,\n        "SL1": 0.0,\n        "SL2": -0.5,\n        "SL3": -0.5\n      },\n      "2": {\n        "SH1": -0.18793687562503408,\n        "SH3": -0.08164073550208747,\n        "SH4": 0.010791414351906451,\n        "SL1": -0.0078039213791843125,\n        "SL2": -0.5023091182393846,\n        "SL3": -0.49637785253243344,\n        "SVD0": 0.017854793408282346\n      },\n      "3": {\n        "SH1": -0.05515944288244379,\n        "SH3": -0.10573846044112414,\n        "SH4": 0.23791540226446983,\n        "SL1": -0.14542166499480047,\n        "SL2": -0.48304203095953685,\n        "SL3": 0.1487552870688007,\n        "SVD0": 0.21457876525819297\n      },\n      "4": {\n        "SH1": -0.016789473401582967,\n        "SH3": -0.11293803470389294,\n        "SH4": 0.3026981410256053,\n        "SL1": -0.18505077449276175,\n        "SL2": -0.4775918402514542,\n        "SL3": 0.37978462509168237,\n        "SVD0": 0.2714668787470421\n       ...
