# %%
import sys
import logging
import json
import numpy as np
import pandas as pd
from datetime import datetime
import time

from apsopt.core.optimizer import Optimizer, get_generator_class
from apsopt.core.evaluators import FunctionEvaluator
from apsopt.util.pydantic.options import AlgorithmOptions
from apsopt.util.pydantic.vocs import GVOCS

logger = logging.getLogger(__name__)

# %% [markdown]
# ### SETUP

# %%
# Load precomputed data

MODE = '6and3'
with open(f'lattice/data_{MODE}.json', 'r') as f:
    data_dict = json.load(f)
groups = data_dict['groups']
groups_direct = data_dict['groups_direct']
all_groups = {**groups, **groups_direct}
indices = data_dict['indices']
null_knobs = data_dict['null_knobs']
dfknobs = pd.read_json(f'lattice/dfknobs_{MODE}.json')

# impact of K2L difference
dfknobs.loc['SM2B',:] *= 0.25/0.2

# DO NOT CHANGE - USED TO CALCULATE ABSOLUTE K2L
initial_values_ref = {
    'SM1A': -23.68063424*0.2,
    'SM2B': 28.64315469*0.25,
    'SM1B': -25.94603546*0.2,
    'SL3': -29.46086061*0.2,
    'SL2': 35.67792145*0.2,
    'SL1': -13.27160605*0.2,
    'SH4': -15.82090071*0.2,
    'SH3': -5.85510841*0.2,
    'SH1': 19.8329121*0.2,
}

# CHANGE THIS TO VALUES FROM RING IF NEEDED
initial_values = initial_values_ref.copy()

initial_values['SM1A'] *= 1.01
initial_values['SM1B'] *= 1.008

# optimizer variables in units of K2L
variables = {'SVD0':[-0.6,0.6]} # this means SM1B will change by ~10%
# variables = {'SVD0':[-0.4,0.4]} # this means SM1B will change by ~10%

for k in ['SH1','SH3','SH4','SL1','SL2','SL3']:
    variables[k] = [-np.abs(initial_values_ref[k])*0.1,np.abs(initial_values_ref[k])*0.1]
    # variables[k] = [-np.abs(initial_values_ref[k])*0.075,np.abs(initial_values_ref[k])*0.075]

objectives_active = {'LT': 'MAXIMIZE', 'EFF':'MAXIMIZE'}

initial_variable_values = {k:0.0 for k in variables.keys()}

# Manual modifications
initial_variable_values['SH1'] -= 0.2
initial_variable_values['SH3'] -= 0.08
initial_variable_values['SL2'] -= 0.5
initial_variable_values['SL3'] -= 0.5

gvocs = GVOCS(variables=variables,
              variables_active=variables,
              objectives=objectives_active,
              objectives_active=objectives_active)

print(pd.DataFrame(initial_values_ref,index=[0]))
print(pd.DataFrame(variables))
# Out:
#        SM1A      SM2B      SM1B       SL3       SL2       SL1      SH4  \
# 0 -4.736127  7.160789 -5.189207 -5.892172  7.135584 -2.654321 -3.16418
#
#         SH3       SH1
# 0 -1.171022  3.966582
#    SVD0       SH1       SH3       SH4       SL1       SL2       SL3
# 0  -0.6 -0.396658 -0.117102 -0.316418 -0.265432 -0.713558 -0.589217
# 1   0.6  0.396658  0.117102  0.316418  0.265432  0.713558  0.589217

# %%
reference_point = {'LT': 3.0, # hours
                   'EFF': 10.0 # % injected
                   }

# %%
import sext_tools
def compute_family_k2l_from_knob_k2l(dfknobs, knobs_dict, debug=False):
    group_relative_strengths = sext_tools.knob_strengths_to_group_strengths(dfknobs, knobs_dict)
    for k in group_relative_strengths:
        if debug:
            print(f'{k}: {initial_values[k]:.3f} + {group_relative_strengths[k]:.3f} -> {initial_values[k]+group_relative_strengths[k]:.3f}')
        group_relative_strengths[k] = group_relative_strengths[k] + initial_values[k]
    return group_relative_strengths

# %%
#TEST = True
TEST = False

if TEST:
    from opt_funcs_nsls import make_dummy_eval
    eval_f = make_dummy_eval(gvocs)
else:
    sys.path.insert(0, "/nsls2/users/yhidaka/git_repos/nsls2scripts3/shifts/2023-11-26_APSU_DA_MA")
    import opt_funcs

    def knobs_to_family(inputs_dict):
        d = compute_family_k2l_from_knob_k2l(dfknobs, inputs_dict, True)
        return opt_funcs.master_eval_function(d, meas_bxb_tunes=True, meas_lifetime=True, meas_inj_eff=True)

    eval_f = knobs_to_family

# %%
inputs_dict = compute_family_k2l_from_knob_k2l(
    dfknobs, {k:variables[k][0] for k in variables.keys()}, True)
inputs_dict
# Out:
# SL1: -2.654 + -0.265 -> -2.920
# SL2: 7.136 + -0.714 -> 6.422
# SL3: -5.892 + -0.589 -> -6.481
# SH1: 3.967 + -0.397 -> 3.570
# SH3: -1.171 + -0.117 -> -1.288
# SH4: -3.164 + -0.316 -> -3.481
# SM1A: -4.783 + 0.398 -> -4.385
# SM1B: -5.231 + -0.447 -> -5.678
# SM2B: 7.161 + 0.052 -> 7.213
# {'SL1': -2.9197533310000003,
#  'SL2': 6.422025861000001,
#  'SL3': -6.481389334200001,
#  'SH1': 3.5699241780000004,
#  'SH3': -1.2881238501999999,
#  'SH4': -3.4805981562,
#  'SM1A': -4.385288760620001,
#  'SM1B': -5.6776103901960004,
#  'SM2B': 7.2127339758749995}

# %%
if True:
    opt_funcs.master_eval_function(inputs_dict, meas_bxb_tunes=True, meas_lifetime=True, meas_inj_eff=True)
# Out:
# Sextupole adj. took 12.6.
# RMS(dx, dy) [m] = (4.703e-05, 4.763e-06)
# RMS(dx, dy) [m] = (1.327e-04, 6.822e-06)
# RMS(dx, dy) [m] = (3.185e-05, 4.989e-06)
# RMS(dx, dy) [m] = (8.485e-05, 5.361e-06)
# RMS(dx, dy) [m] = (1.365e-05, 3.257e-06)
# RMS(dx, dy) [m] = (1.032e-05, 3.919e-06)
# RMS(dx, dy) [m] = (2.087e-05, 8.912e-07)
# RMS(dx, dy) [m] = (7.493e-06, 8.756e-07)
# Orbit correction converged
# ** # of outliers found = 5 (out of 180)
# Lifetime = 3.120 (raw tau [hr] = 3.909, epsy [pm] = 16.42) (took 5.0 [s])
# Inj. Eff. = 36.57 (took 19.4 [s])
# Eval. func. finished.

# %%
ev = FunctionEvaluator(script=eval_f)

generator_name = 'aps_mobo'
gc = get_generator_class(generator_name)

gen = gc(gvocs=gvocs)
gen.numerical_optimizer.n_raw_samples = 128 #512
gen.numerical_optimizer.n_restarts = 10
gen.gp_constructor.use_low_noise_prior = False
gen.gp_constructor.use_high_noise_prior = False
#gen.max_travel_distances = [0.1] * len(gvocs.variables_active)
gen.reference_point = reference_point

# %%
options = AlgorithmOptions(store_history=True, dump_every_step=True)
opt = Optimizer(options=options,
                generator=gen,
                evaluator=ev,
                gvocs=gvocs)

# %% [markdown]
# ### Sample at initial values

# %%
opt.generate_at(initial_variable_values)
opt.evaluate_data()
# Out:
# SL1: -2.654 + 0.000 -> -2.654
# SL2: 7.136 + -0.500 -> 6.636
# SL3: -5.892 + -0.500 -> -6.392
# SH1: 3.967 + -0.200 -> 3.767
# SH3: -1.171 + -0.080 -> -1.251
# SH4: -3.164 + 0.000 -> -3.164
# SM1A: -4.783 + 0.000 -> -4.783
# SM1B: -5.231 + 0.000 -> -5.231
# SM2B: 7.161 + 0.000 -> 7.161
# Sextupole adj. took 5.3.
# RMS(dx, dy) [m] = (1.216e-04, 1.444e-05)
# RMS(dx, dy) [m] = (2.292e-05, 5.847e-06)
# RMS(dx, dy) [m] = (1.561e-04, 7.952e-06)
# RMS(dx, dy) [m] = (1.351e-05, 1.003e-06)
# RMS(dx, dy) [m] = (1.468e-05, 1.109e-06)
# RMS(dx, dy) [m] = (3.689e-06, 1.710e-06)
# Orbit correction converged
# ** # of outliers found = 3 (out of 180)
# Lifetime = 3.846 (raw tau [hr] = 4.818, epsy [pm] = 16.38) (took 4.0 [s])
# Inj. Eff. = 4.19 (took 16.0 [s])
# Eval. func. finished.

# %%
opt.data
# Out:
#    SVD0  SH1   SH3  SH4  SL1  SL2  SL3  \
# 1   0.0 -0.2 -0.08  0.0  0.0 -0.5 -0.5
#
#                                               result exception traceback  ...  \
# 1  {'_nux': 0.20570257065981729, '_nuy': 0.268003...      None            ...
#
#    valid      _nux      _nuy  _eps_x_bxbOn  _eps_y_bxbOn  _eps_x_bxbOff  \
# 1   True  0.205703  0.268004  2.185568e-09  1.653258e-11   2.209514e-09
#
#    _eps_y_bxbOff        LT   _raw_LT       EFF
# 1   1.637865e-11  3.845968  4.818205  4.187326
#
# [1 rows x 22 columns]

# %% [markdown]
# ### Sample close to initial point

# %%
mt = {k: 0.05 for k in variables.keys()}
opt.generate_random_around_point(n=1, point=initial_variable_values, spans=mt, use_normalized_distances=True)
opt.evaluate_data()
# Out:
# SL1: -2.654 + -0.006 -> -2.660
# SL2: 7.136 + -0.482 -> 6.654
# SL3: -5.892 + -0.508 -> -6.400
# SH1: 3.967 + -0.187 -> 3.780
# SH3: -1.171 + -0.080 -> -1.251
# SH4: -3.164 + 0.005 -> -3.159
# SM1A: -4.783 + -0.007 -> -4.790
# SM1B: -5.231 + 0.008 -> -5.223
# SM2B: 7.161 + -0.001 -> 7.160
# Sextupole adj. took 0.1.
# RMS(dx, dy) [m] = (3.790e-05, 1.901e-05)
# RMS(dx, dy) [m] = (1.460e-05, 9.785e-06)
# RMS(dx, dy) [m] = (1.030e-05, 3.007e-06)
# RMS(dx, dy) [m] = (1.773e-05, 9.752e-06)
# RMS(dx, dy) [m] = (6.255e-06, 2.894e-06)
# Orbit correction converged
# ** # of outliers found = 2 (out of 180)
# Lifetime = 3.895 (raw tau [hr] = 4.871, epsy [pm] = 16.34) (took 4.0 [s])
# Inj. Eff. = 2.99 (took 17.0 [s])
# Eval. func. finished.

# %%
opt.data
# Out:
#        SVD0       SH1       SH3      SH4       SL1       SL2       SL3  \
# 1  0.000000 -0.200000 -0.080000  0.00000  0.000000 -0.500000 -0.500000
# 2  0.010133 -0.186588 -0.080199  0.00518 -0.005754 -0.482048 -0.508045
#
#                                               result exception traceback  ...  \
# 1  {'_nux': 0.20570257065981729, '_nuy': 0.268003...      None            ...
# 2  {'_nux': 0.2062773166563648, '_nuy': 0.2672714...      None            ...
#
#    valid      _nux      _nuy  _eps_x_bxbOn  _eps_y_bxbOn  _eps_x_bxbOff  \
# 1   True  0.205703  0.268004  2.185568e-09  1.653258e-11   2.209514e-09
# 2   True  0.206277  0.267271  2.219417e-09  1.645138e-11   2.206530e-09
#
#    _eps_y_bxbOff        LT   _raw_LT       EFF
# 1   1.637865e-11  3.845968  4.818205  4.187326
# 2   1.634399e-11  3.894681  4.871128  2.985835
#
# [2 rows x 22 columns]

# %% [markdown]
# ### Run optimizer

# %%
opt.step()
# Out:
# /nsls2/users/yhidaka/.conda/envs/apsopt311/lib/python3.11/site-packages/botorch/optim/initializers.py:404: BadInitialCandidatesWarning: Unable to find non-zero acquisition function values - initial conditions are being selected randomly.
#   warnings.warn(
# SL1: -2.654 + -0.258 -> -2.912
# SL2: 7.136 + 0.586 -> 7.722
# SL3: -5.892 + 0.366 -> -5.526
# SH1: 3.967 + -0.026 -> 3.940
# SH3: -1.171 + 0.101 -> -1.070
# SH4: -3.164 + 0.237 -> -2.927
# SM1A: -4.783 + 0.320 -> -4.464
# SM1B: -5.231 + -0.359 -> -5.590
# SM2B: 7.161 + 0.042 -> 7.203
# Sextupole adj. took 12.6.
# RMS(dx, dy) [m] = (9.110e-05, 6.466e-06)
# RMS(dx, dy) [m] = (2.457e-05, 4.984e-06)
# RMS(dx, dy) [m] = (5.602e-05, 3.379e-06)
# RMS(dx, dy) [m] = (2.454e-04, 5.854e-06)
# RMS(dx, dy) [m] = (3.498e-05, 4.736e-06)
# RMS(dx, dy) [m] = (2.046e-05, 2.755e-06)
# RMS(dx, dy) [m] = (1.140e-05, 3.127e-06)
# RMS(dx, dy) [m] = (2.454e-05, 6.339e-06)
# RMS(dx, dy) [m] = (4.290e-06, 3.431e-06)
# Orbit correction converged
# ** # of outliers found = 3 (out of 180)
# Lifetime = 11.203 (raw tau [hr] = 14.035, epsy [pm] = 16.44) (took 8.0 [s])
# Inj. Eff. = 7.98 (took 20.1 [s])
# Eval. func. finished.

# %%
for i in range(20):
    print(f'\n** Step #{i+1} at {datetime.now():%Y-%m-%d %H:%M:%S}**\n')
    opt.step()
# Out:
# ** Step #1 at 2023-11-26 22:03:09**
#
# SL1: -2.654 + -0.265 -> -2.919
# SL2: 7.136 + 0.627 -> 7.762
# SL3: -5.892 + 0.384 -> -5.508
# SH1: 3.967 + 0.266 -> 4.233
# SH3: -1.171 + 0.104 -> -1.067
# SH4: -3.164 + 0.242 -> -2.922
# SM1A: -4.783 + 0.328 -> -4.456
# SM1B: -5.231 + -0.368 -> -5.599
# SM2B: 7.161 + 0.043 -> 7.204
# Sextupole adj. took 3.2.
# RMS(dx, dy) [m] = (4.261e-05, 1.853e-06)
# RMS(dx, dy) [m] = (4.139e-05, 3.838e-06)
# RMS(dx, dy) [m] = (1.081e-05, 2.774e-06)
# RMS(dx, dy) [m] = (7.479e-06, 1.065e-06)
# Orbit correction converged
# ** # of outliers found = 3 (out of 180)
# * eps_y too large! Lifetime value set to NaN.
# Lifetime = nan (raw tau [hr] = 20.148, epsy [pm] = 32.58) (took 10.6 [s])
# Inj. Eff. = 2.32 (took 16.0 [s])
# Eval. func. finished.
#
# ** Step #2 at 2023-11-26 22:03:55**
#
# SL1: -2.654 + -0.256 -> -2.911
# SL2: 7.136 + 0.576 -> 7.712
# SL3: -5.892 + 0.363 -> -5.529
# SH1: 3.967 + -0.214 -> 3.752
# SH3: -1.171 + 0.101 -> -1.070
# SH4: -3.164 + 0.236 -> -2.928
# SM1A: -4.783 + 0.319 -> -4.465
# SM1B: -5.231 + -0.357 -> -5.588
# SM2B: 7.161 + 0.042 -> 7.202
# Sextupole adj. took 5.2.
# RMS(dx, dy) [m] = (1.101e-04, 3.833e-06)
# RMS(dx, dy) [m] = (1.402e-04, 4.944e-06)
# RMS(dx, dy) [m] = (2.583e-05, 2.249e-06)
# RMS(dx, dy) [m] = (6.596e-05, 2.562e-06)
# RMS(dx, dy) [m] = (1.001e-05, 2.079e-06)
# RMS(dx, dy) [m] = (4.037e-05, 1.524e-06)
# RMS(dx, dy) [m] = (3.658e-06, 6.218e-07)
# Orbit correction converged
# ** # of outliers found = 5 (out of 180)
# * eps_y too large! Lifetime value set to NaN.
# Lifetime = nan (raw tau [hr] = 12.160, epsy [pm] = 31.21) (took 7.0 [s])
# Inj. Eff. = 13.71 (took 19.3 [s])
# Eval. func. finished.
#
# ** Step #3 at 2023-11-26 22:04:51**
#
# SL1: -2.654 + -0.253 -> -2.908
# SL2: 7.136 + 0.557 -> 7.693
# SL3: -5.892 + 0.357 -> -5.535
# SH1: 3.967 + -0.373 -> 3.593
# SH3: -1.171 + 0.100 -> -1.071
# SH4: -3.164 + 0.234 -> -2.930
# SM1A: -4.783 + 0.316 -> -4.467
# SM1B: -5.231 + -0.355 -> -5.585
# SM2B: 7.161 + 0.041 -> 7.202
# Sextupole adj. took 1.1.
# RMS(dx, dy) [m] = (3.432e-05, 2.076e-06)
# RMS(dx, dy) [m] = (2.281e-05, 4.703e-06)
# RMS(dx, dy) [m] = (6.547e-05, 6.806e-06)
# RMS(dx, dy) [m] = (1.564e-05, 1.248e-06)
# RMS(dx, dy) [m] = (1.948e-05, 8.004e-07)
# RMS(dx, dy) [m] = (5.427e-06, 1.775e-06)
# Orbit correction converged
# ** # of outliers found = 0 (out of 180)
# * eps_y too large! Lifetime value set to NaN.
# Lifetime = nan (raw tau [hr] = 10.382, epsy [pm] = 30.97) (took 6.4 [s])
# Inj. Eff. = 17.89 (took 18.3 [s])
# Eval. func. finished.
#
# ** Step #4 at 2023-11-26 22:05:39**
#
# SL1: -2.654 + -0.213 -> -2.868
# SL2: 7.136 + 0.316 -> 7.452
# SL3: -5.892 + 0.277 -> -5.615
# SH1: 3.967 + -0.397 -> 3.570
# SH3: -1.171 + 0.089 -> -1.082
# SH4: -3.164 + 0.208 -> -2.957
# SM1A: -4.783 + 0.281 -> -4.502
# SM1B: -5.231 + -0.316 -> -5.546
# SM2B: 7.161 + 0.037 -> 7.197
# Sextupole adj. took 2.1.
# RMS(dx, dy) [m] = (2.912e-05, 1.856e-06)
# RMS(dx, dy) [m] = (1.852e-05, 2.926e-06)
# RMS(dx, dy) [m] = (1.838e-05, 3.010e-06)
# RMS(dx, dy) [m] = (1.004e-04, 5.533e-06)
# RMS(dx, dy) [m] = (4.064e-06, 6.991e-07)
# Orbit correction converged
# ** # of outliers found = 5 (out of 180)
# Lifetime = 5.603 (raw tau [hr] = 9.135, epsy [pm] = 27.61) (took 7.1 [s])
# Inj. Eff. = 49.47 (took 19.6 [s])
# Eval. func. finished.
#
# ** Step #5 at 2023-11-26 22:06:27**
#
# SL1: -2.654 + -0.217 -> -2.871
# SL2: 7.136 + 0.259 -> 7.395
# SL3: -5.892 + 0.284 -> -5.608
# SH1: 3.967 + -0.057 -> 3.909
# SH3: -1.171 + 0.090 -> -1.081
# SH4: -3.164 + 0.210 -> -2.954
# SM1A: -4.783 + 0.285 -> -4.498
# SM1B: -5.231 + -0.320 -> -5.551
# SM2B: 7.161 + 0.037 -> 7.198
# Sextupole adj. took 4.2.
# RMS(dx, dy) [m] = (9.468e-05, 8.184e-06)
# RMS(dx, dy) [m] = (1.271e-05, 1.706e-06)
# RMS(dx, dy) [m] = (2.234e-05, 3.003e-06)
# RMS(dx, dy) [m] = (1.308e-05, 1.417e-06)
# RMS(dx, dy) [m] = (9.717e-06, 1.191e-06)
# Orbit correction converged
# ** # of outliers found = 2 (out of 180)
# Lifetime = 5.824 (raw tau [hr] = 9.400, epsy [pm] = 27.03) (took 5.5 [s])
# Inj. Eff. = 59.31 (took 21.1 [s])
# Eval. func. finished.
#
# ** Step #6 at 2023-11-26 22:07:16**
#
# SL1: -2.654 + -0.239 -> -2.893
# SL2: 7.136 + 0.289 -> 7.425
# SL3: -5.892 + 0.328 -> -5.564
# SH1: 3.967 + 0.224 -> 4.190
# SH3: -1.171 + 0.096 -> -1.075
# SH4: -3.164 + 0.224 -> -2.940
# SM1A: -4.783 + 0.303 -> -4.480
# SM1B: -5.231 + -0.340 -> -5.571
# SM2B: 7.161 + 0.040 -> 7.200
# Sextupole adj. took 3.2.
# RMS(dx, dy) [m] = (6.000e-05, 2.197e-06)
# RMS(dx, dy) [m] = (8.025e-06, 1.342e-06)
# Orbit correction converged
# ** # of outliers found = 5 (out of 180)
# Lifetime = 6.901 (raw tau [hr] = 10.937, epsy [pm] = 26.04) (took 7.0 [s])
# Inj. Eff. = 12.33 (took 19.0 [s])
# Eval. func. finished.
#
# ** Step #7 at 2023-11-26 22:07:55**
#
# SL1: -2.654 + -0.202 -> -2.857
# SL2: 7.136 + 0.453 -> 7.589
# SL3: -5.892 + 0.259 -> -5.633
# SH1: 3.967 + -0.102 -> 3.864
# SH3: -1.171 + 0.088 -> -1.083
# SH4: -3.164 + 0.206 -> -2.958
# SM1A: -4.783 + 0.280 -> -4.504
# SM1B: -5.231 + -0.314 -> -5.545
# SM2B: 7.161 + 0.037 -> 7.197
# Sextupole adj. took 3.2.
# RMS(dx, dy) [m] = (2.840e-05, 2.432e-06)
# RMS(dx, dy) [m] = (2.782e-05, 1.896e-06)
# RMS(dx, dy) [m] = (1.418e-05, 2.686e-06)
# RMS(dx, dy) [m] = (7.594e-06, 9.035e-07)
# Orbit correction converged
# ** # of outliers found = 4 (out of 180)
# Lifetime = 6.086 (raw tau [hr] = 9.463, epsy [pm] = 25.03) (took 8.0 [s])
# Inj. Eff. = 22.76 (took 18.9 [s])
# Eval. func. finished.
#
# ** Step #8 at 2023-11-26 22:08:41**
#
# SL1: -2.654 + -0.265 -> -2.920
# SL2: 7.136 + 0.252 -> 7.387
# SL3: -5.892 + 0.426 -> -5.467
# SH1: 3.967 + -0.161 -> 3.805
# SH3: -1.171 + 0.103 -> -1.068
# SH4: -3.164 + 0.238 -> -2.926
# SM1A: -4.783 + 0.322 -> -4.461
# SM1B: -5.231 + -0.361 -> -5.592
# SM2B: 7.161 + 0.042 -> 7.203
# Sextupole adj. took 2.1.
# RMS(dx, dy) [m] = (5.431e-05, 3.293e-06)
# RMS(dx, dy) [m] = (6.300e-05, 4.006e-06)
# RMS(dx, dy) [m] = (1.151e-05, 3.607e-06)
# RMS(dx, dy) [m] = (5.503e-06, 1.522e-06)
# Orbit correction converged
# ** # of outliers found = 3 (out of 180)
# Lifetime = 6.317 (raw tau [hr] = 9.784, epsy [pm] = 24.81) (took 5.5 [s])
# Inj. Eff. = 48.25 (took 18.4 [s])
# Eval. func. finished.
#
# ** Step #9 at 2023-11-26 22:09:22**
#
# SL1: -2.654 + -0.265 -> -2.920
# SL2: 7.136 + 0.167 -> 7.303
# SL3: -5.892 + 0.119 -> -5.773
# SH1: 3.967 + -0.176 -> 3.791
# SH3: -1.171 + 0.086 -> -1.085
# SH4: -3.164 + 0.205 -> -2.959
# SM1A: -4.783 + 0.277 -> -4.506
# SM1B: -5.231 + -0.311 -> -5.542
# SM2B: 7.161 + 0.036 -> 7.197
# Sextupole adj. took 3.2.
# RMS(dx, dy) [m] = (4.337e-05, 2.510e-06)
# RMS(dx, dy) [m] = (1.361e-05, 1.379e-06)
# RMS(dx, dy) [m] = (6.201e-06, 1.901e-06)
# Orbit correction converged
# ** # of outliers found = 9 (out of 180)
# Lifetime = 5.601 (raw tau [hr] = 8.641, epsy [pm] = 24.59) (took 5.9 [s])
# Inj. Eff. = 74.18 (took 19.2 [s])
# Eval. func. finished.
#
# ** Step #10 at 2023-11-26 22:10:03**
#
# SL1: -2.654 + -0.136 -> -2.790
# SL2: 7.136 + 0.053 -> 7.188
# SL3: -5.892 + 0.163 -> -5.729
# SH1: 3.967 + -0.190 -> 3.777
# SH3: -1.171 + 0.087 -> -1.084
# SH4: -3.164 + 0.206 -> -2.959
# SM1A: -4.783 + 0.278 -> -4.506
# SM1B: -5.231 + -0.312 -> -5.542
# SM2B: 7.161 + 0.036 -> 7.197
# Sextupole adj. took 1.1.
# RMS(dx, dy) [m] = (6.420e-05, 2.134e-06)
# RMS(dx, dy) [m] = (1.073e-05, 1.165e-06)
# RMS(dx, dy) [m] = (3.740e-06, 1.539e-06)
# Orbit correction converged
# ** # of outliers found = 3 (out of 180)
# Lifetime = 5.631 (raw tau [hr] = 8.497, epsy [pm] = 23.50) (took 6.1 [s])
# Inj. Eff. = 81.39 (took 20.9 [s])
# Eval. func. finished.
#
# ** Step #11 at 2023-11-26 22:10:44**
#
# SL1: -2.654 + -0.236 -> -2.891
# SL2: 7.136 + -0.036 -> 7.100
# SL3: -5.892 + 0.330 -> -5.562
# SH1: 3.967 + -0.183 -> 3.784
# SH3: -1.171 + 0.069 -> -1.102
# SH4: -3.164 + 0.155 -> -3.009
# SM1A: -4.783 + 0.213 -> -4.570
# SM1B: -5.231 + -0.239 -> -5.470
# SM2B: 7.161 + 0.028 -> 7.189
# Sextupole adj. took 2.1.
# RMS(dx, dy) [m] = (2.342e-05, 1.968e-06)
# RMS(dx, dy) [m] = (7.404e-05, 4.419e-06)
# RMS(dx, dy) [m] = (6.869e-06, 9.399e-07)
# Orbit correction converged
# ** # of outliers found = 15 (out of 180)
# Lifetime = 5.779 (raw tau [hr] = 8.641, epsy [pm] = 23.04) (took 8.5 [s])
# Inj. Eff. = 77.63 (took 18.5 [s])
# Eval. func. finished.
#
# ** Step #12 at 2023-11-26 22:11:27**
#
# SL1: -2.654 + -0.026 -> -2.680
# SL2: 7.136 + -0.050 -> 7.085
# SL3: -5.892 + 0.384 -> -5.508
# SH1: 3.967 + -0.219 -> 3.748
# SH3: -1.171 + 0.075 -> -1.096
# SH4: -3.164 + 0.163 -> -3.001
# SM1A: -4.783 + 0.224 -> -4.559
# SM1B: -5.231 + -0.252 -> -5.483
# SM2B: 7.161 + 0.029 -> 7.190
# Sextupole adj. took 2.1.
# RMS(dx, dy) [m] = (3.437e-05, 2.455e-06)
# RMS(dx, dy) [m] = (8.470e-06, 9.151e-07)
# Orbit correction converged
# ** # of outliers found = 9 (out of 180)
# Lifetime = 5.844 (raw tau [hr] = 8.673, epsy [pm] = 22.68) (took 6.0 [s])
# Inj. Eff. = 41.88 (took 19.1 [s])
# Eval. func. finished.
#
# ** Step #13 at 2023-11-26 22:12:03**
#
# SL1: -2.654 + -0.235 -> -2.890
# SL2: 7.136 + -0.153 -> 6.983
# SL3: -5.892 + 0.085 -> -5.807
# SH1: 3.967 + -0.177 -> 3.789
# SH3: -1.171 + 0.110 -> -1.061
# SH4: -3.164 + 0.218 -> -2.947
# SM1A: -4.783 + 0.302 -> -4.482
# SM1B: -5.231 + -0.338 -> -5.569
# SM2B: 7.161 + 0.039 -> 7.200
# Sextupole adj. took 3.2.
# RMS(dx, dy) [m] = (4.660e-05, 2.521e-06)
# RMS(dx, dy) [m] = (1.938e-05, 3.530e-06)
# RMS(dx, dy) [m] = (1.948e-05, 3.300e-06)
# RMS(dx, dy) [m] = (8.728e-06, 1.853e-06)
# Orbit correction converged
# ** # of outliers found = 6 (out of 180)
# Lifetime = 5.613 (raw tau [hr] = 8.294, epsy [pm] = 22.46) (took 6.6 [s])
# Inj. Eff. = 74.79 (took 20.0 [s])
# Eval. func. finished.
#
# ** Step #14 at 2023-11-26 22:12:48**
#
# SL1: -2.654 + -0.218 -> -2.873
# SL2: 7.136 + -0.021 -> 7.115
# SL3: -5.892 + 0.203 -> -5.689
# SH1: 3.967 + -0.171 -> 3.796
# SH3: -1.171 + 0.048 -> -1.123
# SH4: -3.164 + 0.259 -> -2.905
# SM1A: -4.783 + 0.365 -> -4.419
# SM1B: -5.231 + -0.410 -> -5.640
# SM2B: 7.161 + 0.048 -> 7.208
# Sextupole adj. took 1.1.
# RMS(dx, dy) [m] = (7.791e-07, 1.076e-06)
# Orbit correction converged
# ** # of outliers found = 12 (out of 180)
# Lifetime = 6.013 (raw tau [hr] = 8.829, epsy [pm] = 22.16) (took 8.1 [s])
# Inj. Eff. = 76.54 (took 19.3 [s])
# Eval. func. finished.
#
# ** Step #15 at 2023-11-26 22:13:24**
#
# SL1: -2.654 + -0.218 -> -2.872
# SL2: 7.136 + 0.012 -> 7.148
# SL3: -5.892 + 0.220 -> -5.672
# SH1: 3.967 + -0.154 -> 3.813
# SH3: -1.171 + 0.079 -> -1.092
# SH4: -3.164 + 0.316 -> -2.848
# SM1A: -4.783 + 0.161 -> -4.622
# SM1B: -5.231 + -0.181 -> -5.412
# SM2B: 7.161 + 0.021 -> 7.182
# Sextupole adj. took 2.1.
# RMS(dx, dy) [m] = (4.738e-05, 2.240e-06)
# RMS(dx, dy) [m] = (3.171e-05, 1.790e-06)
# RMS(dx, dy) [m] = (1.415e-05, 2.871e-06)
# RMS(dx, dy) [m] = (8.563e-06, 1.924e-06)
# Orbit correction converged
# ** # of outliers found = 5 (out of 180)
# Lifetime = 5.804 (raw tau [hr] = 8.465, epsy [pm] = 21.84) (took 7.5 [s])
# Inj. Eff. = 68.13 (took 19.5 [s])
# Eval. func. finished.
#
# ** Step #16 at 2023-11-26 22:14:09**
#
# SL1: -2.654 + -0.230 -> -2.884
# SL2: 7.136 + -0.001 -> 7.134
# SL3: -5.892 + 0.268 -> -5.624
# SH1: 3.967 + -0.397 -> 3.570
# SH3: -1.171 + 0.098 -> -1.073
# SH4: -3.164 + 0.196 -> -2.968
# SM1A: -4.783 + 0.398 -> -4.385
# SM1B: -5.231 + -0.447 -> -5.678
# SM2B: 7.161 + 0.052 -> 7.213
# Sextupole adj. took 3.2.
# RMS(dx, dy) [m] = (4.967e-05, 4.301e-06)
# RMS(dx, dy) [m] = (1.374e-04, 9.603e-06)
# RMS(dx, dy) [m] = (2.220e-05, 2.465e-06)
# RMS(dx, dy) [m] = (2.584e-05, 2.538e-06)
# RMS(dx, dy) [m] = (1.022e-05, 2.109e-06)
# RMS(dx, dy) [m] = (7.115e-06, 1.957e-06)
# Orbit correction converged
# ** # of outliers found = 4 (out of 180)
# Lifetime = 6.185 (raw tau [hr] = 8.983, epsy [pm] = 21.63) (took 6.1 [s])
# Inj. Eff. = 73.99 (took 20.1 [s])
# Eval. func. finished.
#
# ** Step #17 at 2023-11-26 22:15:00**
#
# SL1: -2.654 + -0.227 -> -2.881
# SL2: 7.136 + -0.044 -> 7.092
# SL3: -5.892 + 0.028 -> -5.864
# SH1: 3.967 + -0.397 -> 3.570
# SH3: -1.171 + 0.043 -> -1.128
# SH4: -3.164 + 0.132 -> -3.032
# SM1A: -4.783 + 0.398 -> -4.385
# SM1B: -5.231 + -0.447 -> -5.678
# SM2B: 7.161 + 0.052 -> 7.213
# Sextupole adj. took 2.1.
# RMS(dx, dy) [m] = (4.428e-05, 5.360e-06)
# RMS(dx, dy) [m] = (1.628e-05, 3.100e-06)
# RMS(dx, dy) [m] = (8.980e-06, 3.767e-06)
# Orbit correction converged
# ** # of outliers found = 6 (out of 180)
# Lifetime = 5.572 (raw tau [hr] = 8.018, epsy [pm] = 21.22) (took 7.3 [s])
# Inj. Eff. = 79.61 (took 18.8 [s])
# Eval. func. finished.
#
# ** Step #18 at 2023-11-26 22:15:40**
#
# SL1: -2.654 + -0.244 -> -2.899
# SL2: 7.136 + -0.313 -> 6.822
# SL3: -5.892 + 0.216 -> -5.676
# SH1: 3.967 + -0.359 -> 3.608
# SH3: -1.171 + 0.056 -> -1.115
# SH4: -3.164 + 0.144 -> -3.020
# SM1A: -4.783 + 0.398 -> -4.385
# SM1B: -5.231 + -0.447 -> -5.678
# SM2B: 7.161 + 0.052 -> 7.213
# Sextupole adj. took 3.2.
# RMS(dx, dy) [m] = (3.534e-05, 1.801e-06)
# RMS(dx, dy) [m] = (7.536e-05, 5.053e-06)
# RMS(dx, dy) [m] = (2.407e-05, 3.380e-06)
# RMS(dx, dy) [m] = (9.993e-06, 1.446e-06)
# Orbit correction converged
# ** # of outliers found = 4 (out of 180)
# Lifetime = 5.527 (raw tau [hr] = 7.893, epsy [pm] = 20.88) (took 5.3 [s])
# Inj. Eff. = 79.03 (took 18.4 [s])
# Eval. func. finished.
#
# ** Step #19 at 2023-11-26 22:16:23**
#
# SL1: -2.654 + -0.261 -> -2.915
# SL2: 7.136 + -0.572 -> 6.563
# SL3: -5.892 + 0.213 -> -5.679
# SH1: 3.967 + -0.364 -> 3.602
# SH3: -1.171 + 0.072 -> -1.099
# SH4: -3.164 + 0.149 -> -3.016
# SM1A: -4.783 + 0.398 -> -4.385
# SM1B: -5.231 + -0.447 -> -5.678
# SM2B: 7.161 + 0.052 -> 7.213
# Sextupole adj. took 3.2.
# RMS(dx, dy) [m] = (4.916e-05, 2.786e-06)
# RMS(dx, dy) [m] = (1.714e-05, 2.300e-06)
# RMS(dx, dy) [m] = (2.155e-05, 2.964e-06)
# RMS(dx, dy) [m] = (1.472e-05, 9.411e-07)
# RMS(dx, dy) [m] = (8.424e-06, 8.308e-07)
# Orbit correction converged
# ** # of outliers found = 4 (out of 180)
# Lifetime = 5.308 (raw tau [hr] = 7.567, epsy [pm] = 20.79) (took 5.2 [s])
# Inj. Eff. = 32.51 (took 20.9 [s])
# Eval. func. finished.
#
# ** Step #20 at 2023-11-26 22:17:11**
#
# SL1: -2.654 + -0.182 -> -2.837
# SL2: 7.136 + -0.138 -> 6.998
# SL3: -5.892 + 0.189 -> -5.703
# SH1: 3.967 + -0.298 -> 3.668
# SH3: -1.171 + 0.068 -> -1.103
# SH4: -3.164 + 0.145 -> -3.019
# SM1A: -4.783 + 0.374 -> -4.409
# SM1B: -5.231 + -0.420 -> -5.651
# SM2B: 7.161 + 0.049 -> 7.210
# Sextupole adj. took 5.2.
# RMS(dx, dy) [m] = (7.970e-05, 5.374e-06)
# RMS(dx, dy) [m] = (5.184e-05, 4.540e-06)
# RMS(dx, dy) [m] = (2.524e-05, 3.545e-06)
# RMS(dx, dy) [m] = (1.234e-05, 1.883e-06)
# RMS(dx, dy) [m] = (7.948e-06, 3.233e-06)
# Orbit correction converged
# ** # of outliers found = 2 (out of 180)
# Lifetime = 6.107 (raw tau [hr] = 8.682, epsy [pm] = 20.65) (took 7.7 [s])
# Inj. Eff. = 81.48 (took 18.4 [s])
# Eval. func. finished.

# %%
opt.data.tail()
# Out:
#         SVD0       SH1       SH3       SH4       SL1       SL2       SL3  \
# 19 -0.600000 -0.396658  0.098329  0.195902 -0.229587 -0.001383  0.268022
# 20 -0.600000 -0.396658  0.043288  0.132499 -0.226838 -0.043730  0.027900
# 21 -0.600000 -0.358636  0.056398  0.143851 -0.244280 -0.313159  0.215822
# 22 -0.600000 -0.364217  0.071591  0.148611 -0.260660 -0.572413  0.213397
# 23 -0.563915 -0.298333  0.068341  0.145066 -0.182403 -0.137754  0.189494
#
#                                                result exception traceback  \
# 19  {'_nux': 0.2180773739976842, '_nuy': 0.2502427...      None
# 20  {'_nux': 0.21433391170065594, '_nuy': 0.254332...      None
# 21  {'_nux': 0.21429322671260673, '_nuy': 0.249408...      None
# 22  {'_nux': 0.21295046087189154, '_nuy': 0.254240...      None
# 23  {'_nux': 0.2169787583940371, '_nuy': 0.2526841...      None
#
#     ...  valid      _nux      _nuy  _eps_x_bxbOn  _eps_y_bxbOn  _eps_x_bxbOff  \
# 19  ...   True  0.218077  0.250243  2.154246e-09  2.186441e-11   2.148658e-09
# 20  ...   True  0.214334  0.254332  2.168691e-09  1.962091e-11   2.151992e-09
# 21  ...   True  0.214293  0.249409  2.181822e-09  1.944598e-11   2.152788e-09
# 22  ...   True  0.212950  0.254241  2.159715e-09  1.917068e-11   2.153457e-09
# 23  ...   True  0.216979  0.252684  2.151863e-09  2.030655e-11   2.154666e-09
#
#     _eps_y_bxbOff        LT   _raw_LT        EFF
# 19   2.163378e-11  6.185407  8.982627  73.992345
# 20   2.121955e-11  5.571952  8.018319  79.605385
# 21   2.088089e-11  5.526967  7.893065  79.032110
# 22   2.078809e-11  5.308303  7.566539  32.514590
# 23   2.065316e-11  6.107185  8.681939  81.482580
#
# [5 rows x 22 columns]

# %%
import matplotlib.pyplot as plt

hvs = []
for i in range(1,len(opt.data)):
    hv = opt.generator.calculate_hypervolume_at(i)
    hvs.append(hv)

fig,ax = plt.subplots(1,2,squeeze=False,figsize=(12,6))
df = opt.data
ol = ['EFF', 'LT']
l = ax[0,0].scatter(df.loc[:,ol[0]], df.loc[:,ol[1]],10,marker='o',c=range(len(df)),vmax=len(df))
ax[0,0].scatter(df.loc[:1,ol[0]], df.loc[:1,ol[1]], 20,marker='o',c='red',label='initial point')
ax[0,0].scatter(gen.reference_point[ol[0]], gen.reference_point[ol[1]],40,marker='*',c='black',label='reference point')
ax[0,0].set_xlabel(ol[0])
ax[0,0].set_ylabel(ol[1])
fig.colorbar(l)
ax[0,0].legend()

ax[0,1].plot(hvs,marker='o')
ax[0,1].set_xlabel('Step #')
ax[0,1].set_ylabel('Hypervolume')
# Out:
# Text(0, 0.5, 'Hypervolume')

# %%
hvs
# Out:
# [0.0,
#  0.0,
#  0.0,
#  0.0,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf,
#  inf]

# %%
fig,ax = plt.subplots(1,2,squeeze=False,figsize=(8,6))
df = opt.data

ax[0,0].plot(df.loc[:,'_nux'], marker='o', label='nux')
ax[0,0].plot(df.loc[:,'_nuy'], marker='o', label='nuy')
ax[0,1].plot(df.loc[:,'_eps_x_bxbOn'], marker='o', label='eps_x_bxbOn', color='red')
ax[0,1].plot(df.loc[:,'_eps_y_bxbOn']*1e2, marker='o', label='eps_y_bxbOn', color='green')
ax[0,0].set_xlabel('Step #')
ax[0,0].set_ylabel('Tune')
ax[0,0].legend()
ax[0,1].legend()

# %%
# This will save optimizer state
from datetime import datetime
opt.state_to_json(f'{datetime.now():%Y%m%dT%H%M%S}_exp_mobo_{MODE}_v1_dump.json')
# Out:
# '{\n  "optimizer": {\n    "tag": "df860ddc2a",\n    "store_history": true,\n    "dump_every_step": true,\n    "history_directory": null,\n    "execution_mode": "sync"\n  },\n  "generator": {\n    "name": "aps_mobo",\n    "n_monte_carlo_samples": 128,\n    "turbo_controller": null,\n    "use_cuda": false,\n    "gp_constructor": {\n      "name": "mobo_model",\n      "use_low_noise_prior": false,\n      "covar_modules": {},\n      "mean_modules": {},\n      "trainable_mean_keys": [],\n      "use_high_noise_prior": false\n    },\n    "numerical_optimizer": {\n      "name": "APSLBFGS",\n      "n_raw_samples": 128,\n      "n_restarts": 10,\n      "max_iter": 2000,\n      "sequential": true\n    },\n    "max_travel_distances": null,\n    "fixed_features": null,\n    "computation_time": null,\n    "n_candidates": 1,\n    "reference_point": {\n      "LT": 3.0,\n      "EFF": 10.0\n    },\n    "prune_inferior_points_kwargs": null\n  },\n  "evaluator": {\n    "name": "func",\n    "on_error": "ignore",\n    "max_workers": 1,\n    "script": "__main__.knobs_to_family",\n    "post_script": null,\n    "script_kwargs": {},\n    "eval_cnt": 23,\n    "TRACE": true\n  },\n  "gvocs": {\n    "variables": {\n      "SVD0": [\n        -0.6,\n        0.6\n      ],\n      "SH1": [\n        -0.39665824200000005,\n        0.39665824200000005\n      ],\n      "SH3": [\n        -0.1171021682,\n        0.1171021682\n      ],\n      "SH4": [\n        -0.31641801420000004,\n        0.31641801420000004\n      ],\n      "SL1": [\n        -0.2654321210000001,\n        0.2654321210000001\n      ],\n      "SL2": [\n        -0.7135584290000001,\n        0.7135584290000001\n      ],\n      "SL3": [\n        -0.5892172122000001,\n        0.5892172122000001\n      ]\n    },\n    "variables_active": {\n      "SVD0": [\n        -0.6,\n        0.6\n      ],\n      "SH1": [\n        -0.39665824200000005,\n        0.39665824200000005\n      ],\n      "SH3": [\n        -0.1171021682,\n        0.1171021682\n      ],\n      "SH4": [\n        -0.31641801420000004,\n        0.31641801420000004\n      ],\n      "SL1": [\n        -0.2654321210000001,\n        0.2654321210000001\n      ],\n      "SL2": [\n        -0.7135584290000001,\n        0.7135584290000001\n      ],\n      "SL3": [\n        -0.5892172122000001,\n        0.5892172122000001\n      ]\n    },\n    "auxiliary": {},\n    "readbacks": {},\n    "constraints": {},\n    "constraints_active": {},\n    "objectives": {\n      "LT": "MAXIMIZE",\n      "EFF": "MAXIMIZE"\n    },\n    "objectives_active": {\n      "LT": "MAXIMIZE",\n      "EFF": "MAXIMIZE"\n    },\n    "observables": [],\n    "atol": {\n      "SH1": 0.05,\n      "SH3": 0.05,\n      "SH4": 0.05,\n      "SL1": 0.05,\n      "SL2": 0.05,\n      "SL3": 0.05,\n      "SVD0": 0.05\n    },\n    "initial_change": {},\n    "constants": {},\n    "linked_variables": {},\n    "knobs": {},\n    "knobs_initial_values": {}\n  },\n  "data": {\n    "input_data": {\n      "1": {\n        "SVD0": 0.0,\n        "SH1": -0.2,\n        "SH3": -0.08,\n        "SH4": 0.0,\n        "SL1": 0.0,\n        "SL2": -0.5,\n        "SL3": -0.5\n      },\n      "2": {\n        "SH1": -0.1865876154468148,\n        "SH3": -0.08019931221244424,\n        "SH4": 0.005179962126110171,\n        "SL1": -0.005753970431669734,\n        "SL2": -0.4820475181742487,\n        "SL3": -0.5080451084234533,\n        "SVD0": 0.010132660347872323\n      },\n      "3": {\n        "SH1": -0.02618298505935085,\n        "SH3": 0.10132601147396933,\n        "SH4": 0.2368317359119051,\n        "SL1": -0.2578411346681417,\n        "SL2": 0.5862678293775658,\n        "SL3": 0.3657904845455684,\n        "SVD0": -0.48203923702239987\n      },\n      "4": {\n        "SH1": 0.2663769023563357,\n        "SH3": 0.10446394539233014,\n        "SH4": 0.2418572714742511,\n        "SL1": -0.264986868872994,\n        "SL2": 0.6266951458638003,\n        "SL3": 0.3842639072881385,\n        "SVD0": -0.4939270778193566\n      },\n      "5": ...
